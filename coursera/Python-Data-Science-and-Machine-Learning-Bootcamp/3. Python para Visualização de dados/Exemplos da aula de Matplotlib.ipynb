# %% [markdown]
# # 1a aula

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x * x

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Functional
plt.plot(x,y,'r--')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
# Out:
# Text(0,0.5,'Eixo Y')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'g*-')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.3,0.3])

axes1.plot(x,y)
axes1.set_xlabel('Eixo X')
axes1.set_ylabel('Eixo Y')
axes1.set_title('Título')
axes2.plot(y,x)

# %% [markdown]
# # 2a aula

# %%
fig, kj = plt.subplots()
kj.plot([1,83,75],'g--')

# %%
fig, fitness = plt.subplots()
kenji = [86, 80 ]
triste = [96, 90 ]
comando = [93, 89 ]
fitness.plot(kenji,'g--')
fitness.plot(triste,'b--')
fitness.plot(comando,'r--')
