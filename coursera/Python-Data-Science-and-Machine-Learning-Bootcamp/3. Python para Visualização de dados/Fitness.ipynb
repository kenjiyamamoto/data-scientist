# %%
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerLine2D

# %matplotlib inline
import numpy as np

# %%
fig, fitness = plt.subplots()
kenji = [86, 80]
triste = [96, 90 ]
comando = [93, 89 ]
datas = ["01/JAN","02/JAN"]

plt.rcParams["figure.figsize"] = (20,10)
plt.scatter(range(len(kenji)), kenji, label='Kenji')
plt.plot(range(len(kenji)), kenji, label='_nolengend_')
plt.scatter(range(len(triste)), triste, label='Triste')
plt.plot(range(len(triste)), triste, label='_nolengend_')
plt.scatter(range(len(comando)), comando, label='Comando')
plt.plot(range(len(comando)), comando, label='_nolengend_')
plt.grid(which="major")
plt.legend(fontsize=25)
plt.xticks(np.arange(len(datas)),datas,fontsize=25)
plt.yticks(fontsize=25)
plt.title("Fitness Challenge - The BIGGEST Loser!",fontsize=25)
plt.show()
